# %% [markdown]
# # pandas の DataFrame を用い，行列（表）データを扱う
#
# 行データを拡張し，いよいよ表データを扱います！！
#
# これを使いこなせるようになるのが，これまで3回の最終目標です！
#
# ## 目標
# - DataFrame のデータを概観できる
# - DataFrame を適切に参照できる
# - DataFrame を定義する方法を知る
#
# ## 目次
# - データの特徴をつかむ
# - DataFrame を参照する
# - DataFrame を定義する

# %%
import pandas as pd
from pandas import DataFrame, Series

# %%
# データの読み込み
import sklearn.datasets
data = sklearn.datasets.load_linnerud()
df = DataFrame(data.data, columns=data.feature_names).join(
    DataFrame(data.target, columns=data.target_names))

# 表示
df
# Out:
#     Chins  Situps  Jumps  Weight  Waist  Pulse
# 0     5.0   162.0   60.0   191.0   36.0   50.0
# 1     2.0   110.0   60.0   189.0   37.0   52.0
# 2    12.0   101.0  101.0   193.0   38.0   58.0
# 3    12.0   105.0   37.0   162.0   35.0   62.0
# 4    13.0   155.0   58.0   189.0   35.0   46.0
# 5     4.0   101.0   42.0   182.0   36.0   56.0
# 6     8.0   101.0   38.0   211.0   38.0   56.0
# 7     6.0   125.0   40.0   167.0   34.0   60.0
# 8    15.0   200.0   40.0   176.0   31.0   74.0
# 9    17.0   251.0  250.0   154.0   33.0   56.0
# 10   17.0   120.0   38.0   169.0   34.0   50.0
# 11   13.0   210.0  115.0   166.0   33.0   52.0
# 12   14.0   215.0  105.0   154.0   34.0   64.0
# 13    1.0    50.0   50.0   247.0   46.0   50.0
# 14    6.0    70.0   31.0   193.0   36.0   46.0
# 15   12.0   210.0  120.0   202.0   37.0   62.0
# 16    4.0    60.0   25.0   176.0   37.0   54.0
# 17   11.0   230.0   80.0   157.0   32.0   52.0
# 18   15.0   225.0   73.0   156.0   33.0   54.0
# 19    2.0   110.0   43.0   138.0   33.0   68.0

# %% [markdown]
# ## データの特徴をつかむ
#
# データを読み込んで，まずはどのようなデータか概観したいときに用いるメソッドを紹介する。
#
# - columns
# - head()
# - describe()
# - hist()
# - scatter()

# %%
# 先頭5行を表示する

df.head()
# Out:
#    Chins  Situps  Jumps  Weight  Waist  Pulse
# 0    5.0   162.0   60.0   191.0   36.0   50.0
# 1    2.0   110.0   60.0   189.0   37.0   52.0
# 2   12.0   101.0  101.0   193.0   38.0   58.0
# 3   12.0   105.0   37.0   162.0   35.0   62.0
# 4   13.0   155.0   58.0   189.0   35.0   46.0

# %%
# 列名を確認する

df.columns
# Out:
# Index(['Chins', 'Situps', 'Jumps', 'Weight', 'Waist', 'Pulse'], dtype='object')

# %%
# 統計量を確認する

df.describe()
# Out:
#            Chins      Situps      Jumps      Weight      Waist      Pulse
# count  20.000000   20.000000   20.00000   20.000000  20.000000  20.000000
# mean    9.450000  145.550000   70.30000  178.600000  35.400000  56.100000
# std     5.286278   62.566575   51.27747   24.690505   3.201973   7.210373
# min     1.000000   50.000000   25.00000  138.000000  31.000000  46.000000
# 25%     4.750000  101.000000   39.50000  160.750000  33.000000  51.500000
# 50%    11.500000  122.500000   54.00000  176.000000  35.000000  55.000000
# 75%    13.250000  210.000000   85.25000  191.500000  37.000000  60.500000
# max    17.000000  251.000000  250.00000  247.000000  46.000000  74.000000

# %%
# 分布を確認する

df.hist()
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\simon\Anaconda3\envs\data\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C93C0740C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C93DD7A808>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C93DDB2548>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C93DDF2E48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001C93DE24788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001C93DE5C888>]],
#       dtype=object)
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Noto Sans CJK JP'] not found. Falling back to DejaVu Sans.

# %%
# 分布を確認する（特定の列）

df.hist('Waist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C93E04A988>]],
#       dtype=object)

# %%
# 散布図

df.plot.scatter('Weight', 'Waist')

# %% [markdown]
# ## DataFrame を参照する
#
# 適切にデータを参照する方法を学ぶ。
#
# 全てのデータを分析対象とすることは少ない。分析対象のデータのみを参照したうえで，データの集計・分析・グラフ化を行う。

# %%
# 列を参照する (1)

# Weight 列の参照 [] を使う
df['Weight']
# Out:
# 0     191.0
# 1     189.0
# 2     193.0
# 3     162.0
# 4     189.0
# 5     182.0
# 6     211.0
# 7     167.0
# 8     176.0
# 9     154.0
# 10    169.0
# 11    166.0
# 12    154.0
# 13    247.0
# 14    193.0
# 15    202.0
# 16    176.0
# 17    157.0
# 18    156.0
# 19    138.0
# Name: Weight, dtype: float64

# %%
# 列を参照する (2)

# Weight 列の参照 . を使う
df.Weight
# Out:
# 0     191.0
# 1     189.0
# 2     193.0
# 3     162.0
# 4     189.0
# 5     182.0
# 6     211.0
# 7     167.0
# 8     176.0
# 9     154.0
# 10    169.0
# 11    166.0
# 12    154.0
# 13    247.0
# 14    193.0
# 15    202.0
# 16    176.0
# 17    157.0
# 18    156.0
# 19    138.0
# Name: Weight, dtype: float64

# %%
# 行を参照する

# インデックスが 0 の列を参照する
df.loc[0]  # [] の中にインデックスラベルを入れる
# Out:
# Chins       5.0
# Situps    162.0
# Jumps      60.0
# Weight    191.0
# Waist      36.0
# Pulse      50.0
# Name: 0, dtype: float64

# %%
# 1行，複数列を参照する (1) 連続する列

# インデックスが 0 の人の， Weight ~ Pulse を参照する。

df.loc[0, 'Weight':'Pulse']  # インデックス，列名スライス
# Out:
# Weight    191.0
# Waist      36.0
# Pulse      50.0
# Name: 0, dtype: float64

# %%
# 1行，複数列を参照する (2) とびとびの列

# インデックスが 0 の人の，'Situps','Waist','Pulse' 列を参照する。

df.loc[0, ['Situps','Waist','Pulse']]  # インデックス，列名のリスト
# Out:
# Situps    162.0
# Waist      36.0
# Pulse      50.0
# Name: 0, dtype: float64

# %%
# 複数行，1列を参照する (1) 連続する列

# インデックスが 0から2 の人の，Weight 列を参照する。

df.loc[0:2, 'Weight']  # インデックススライス，列名
# Out:
# 0    191.0
# 1    189.0
# 2    193.0
# Name: Weight, dtype: float64

# %%
# 複数行，1列を参照する (2) とびとびの列

# インデックスが 0,2,4,6 の人の，Weight 列を参照する。

df.loc[[0, 2, 4, 6], 'Weight']  # インデックスのリスト，列名
# Out:
# 0    191.0
# 2    193.0
# 4    189.0
# 6    211.0
# Name: Weight, dtype: float64

# %% [markdown]
# ### スライスの挙動
#
# - Python の通常のスライス（リストのスライスなど）
#   - 末尾は含まない
# - pandas のスライス
#   - 末尾を含む

# %% [markdown]
# Python スライスを確認する

# %%
arr = [3, 9, 27, 81, 243]

print('リストのスライス = Python スライス')
print('  arr[0:3] --> インデックス番号0から2，3つ表示')
print()
print(arr[0:3])
# Out:
# リストのスライス = Python スライス
#   arr[0:3] --> インデックス番号0から2，3つ表示
#
# [3, 9, 27]

# %% [markdown]
# pandas の DataFrame・Series は，pandas スライスと Python スライスの，どちらも使用できる

# %%
print('DataFrame だが Python スライスを用いる場合')
print('  df[0:3] --> pandasのインデックス番号0から2，3つ表示')
print()
print(df[0:3])

print()
print('DataFrame で pandas スライスを用いる')
print('  df.loc[0:3, :] --> pandasのインデックスラベル0から3，4つ表示')
print()
print(df.loc[0:3, :])
# Out:
# DataFrame だが Python スライスを用いる場合
#   df[0:3] --> pandasのインデックス番号0から2，3つ表示
#
#    Chins  Situps  Jumps  Weight  Waist  Pulse
# 0    5.0   162.0   60.0   191.0   36.0   50.0
# 1    2.0   110.0   60.0   189.0   37.0   52.0
# 2   12.0   101.0  101.0   193.0   38.0   58.0
#
# DataFrame で pandas スライスを用いる
#   df.loc[0:3, :] --> pandasのインデックスラベル0から3，4つ表示
#
#    Chins  Situps  Jumps  Weight  Waist  Pulse
# 0    5.0   162.0   60.0   191.0   36.0   50.0
# 1    2.0   110.0   60.0   189.0   37.0   52.0
# 2   12.0   101.0  101.0   193.0   38.0   58.0
# 3   12.0   105.0   37.0   162.0   35.0   62.0

# %% [markdown]
# ### 推奨
#
# 書いているコードが，Python スライスなのか，pandas スライスなのか混同するのが一番よくない。pandas の DataFrame, Series でスライスする方法を自分の中で統一する必要がある。
#
# **推奨するのは，pandas の参照には基本的にすべて .loc() を用うこと。**
#
# .loc() で参照する場合は，pandas スライスとなるので，スライスの末尾を含む。インデックスラベル・列名ラベルを用いる。

# %%
# 複数行，複数列を参照する (1) 連続

# インデックスが 0から5 の人の， Weight ~ Pulse 列を参照する。

df.loc[0:5, 'Weight':'Pulse']
# Out:
#    Weight  Waist  Pulse
# 0   191.0   36.0   50.0
# 1   189.0   37.0   52.0
# 2   193.0   38.0   58.0
# 3   162.0   35.0   62.0
# 4   189.0   35.0   46.0
# 5   182.0   36.0   56.0

# %%
# 複数行，複数列を参照する (1) 飛び飛び

# インデックスが 2,4,6 の人の， Chins,Weight 列を参照する。

df.loc[[2,4,6], ['Chins', 'Weight']]
# Out:
#    Chins  Weight
# 2   12.0   193.0
# 4   13.0   189.0
# 6    8.0   211.0

# %%
# 全行，複数列を参照する

# 全員の，Weight ~ Pulse 列を参照する。
# 全部を参照するには，コロン(:)を用い，左右に何も書かない。

df.loc[:, 'Weight':'Pulse']
# Out:
#     Weight  Waist  Pulse
# 0    191.0   36.0   50.0
# 1    189.0   37.0   52.0
# 2    193.0   38.0   58.0
# 3    162.0   35.0   62.0
# 4    189.0   35.0   46.0
# 5    182.0   36.0   56.0
# 6    211.0   38.0   56.0
# 7    167.0   34.0   60.0
# 8    176.0   31.0   74.0
# 9    154.0   33.0   56.0
# 10   169.0   34.0   50.0
# 11   166.0   33.0   52.0
# 12   154.0   34.0   64.0
# 13   247.0   46.0   50.0
# 14   193.0   36.0   46.0
# 15   202.0   37.0   62.0
# 16   176.0   37.0   54.0
# 17   157.0   32.0   52.0
# 18   156.0   33.0   54.0
# 19   138.0   33.0   68.0

# %%
# セルを参照する (1) loc

# インデックスが 0 の人の， Weight 列を参照する。

df.loc[0, 'Weight']
# Out:
# 191.0

# %%
# セルを参照する (2) at (推奨)
# 書き方は loc と全く同じ。

# インデックスが 0 の人の， Weight 列を参照する。

df.at[0, 'Weight']  # .loc と結果は同じだが，セル参照の内部処理は， .at が最適
# Out:
# 191.0

# %% [markdown]
# (参考・非推奨) loc の代わりにiloc，atの代わりにiatを用いると，Python インデックスを用いた参照ができる

# %% [markdown]
# ### True, False を用いた参照

# %%
df < 50
# Out:
#     Chins  Situps  Jumps  Weight  Waist  Pulse
# 0    True   False  False   False   True  False
# 1    True   False  False   False   True  False
# 2    True   False  False   False   True  False
# 3    True   False   True   False   True  False
# 4    True   False  False   False   True   True
# 5    True   False   True   False   True  False
# 6    True   False   True   False   True  False
# 7    True   False   True   False   True  False
# 8    True   False   True   False   True  False
# 9    True   False  False   False   True  False
# 10   True   False   True   False   True  False
# 11   True   False  False   False   True  False
# 12   True   False  False   False   True  False
# 13   True   False  False   False   True  False
# 14   True   False   True   False   True   True
# 15   True   False  False   False   True  False
# 16   True   False   True   False   True  False
# 17   True   False  False   False   True  False
# 18   True   False  False   False   True  False
# 19   True   False   True   False   True  False

# %%
# よくやる使い方
df[df.Jumps < 50]
# Out:
#     Chins  Situps  Jumps  Weight  Waist  Pulse
# 3    12.0   105.0   37.0   162.0   35.0   62.0
# 5     4.0   101.0   42.0   182.0   36.0   56.0
# 6     8.0   101.0   38.0   211.0   38.0   56.0
# 7     6.0   125.0   40.0   167.0   34.0   60.0
# 8    15.0   200.0   40.0   176.0   31.0   74.0
# 10   17.0   120.0   38.0   169.0   34.0   50.0
# 14    6.0    70.0   31.0   193.0   36.0   46.0
# 16    4.0    60.0   25.0   176.0   37.0   54.0
# 19    2.0   110.0   43.0   138.0   33.0   68.0

# %%
# 条件で絞った上で，必要なデータのみ取り出すとき

# Jumps < 50 の人すべての， Chins ~ Jumps の参照。

df[df.Jumps < 50].loc[:, 'Chins':'Jumps']
# Out:
#     Chins  Situps  Jumps
# 3    12.0   105.0   37.0
# 5     4.0   101.0   42.0
# 6     8.0   101.0   38.0
# 7     6.0   125.0   40.0
# 8    15.0   200.0   40.0
# 10   17.0   120.0   38.0
# 14    6.0    70.0   31.0
# 16    4.0    60.0   25.0
# 19    2.0   110.0   43.0

# %% [markdown]
# ### 練習
#
# 体重が 180 以上の人の，懸垂の成績・体重・ウェストを出力してください

# %%
# 体重が 180 以上の人の，懸垂の成績・体重・ウェストを出力する

df[df.Weight >= 180].loc[:, ['Chins', 'Weight', 'Waist']]
# Out:
#     Chins  Weight  Waist
# 0     5.0   191.0   36.0
# 1     2.0   189.0   37.0
# 2    12.0   193.0   38.0
# 4    13.0   189.0   35.0
# 5     4.0   182.0   36.0
# 6     8.0   211.0   38.0
# 13    1.0   247.0   46.0
# 14    6.0   193.0   36.0
# 15   12.0   202.0   37.0

# %% [markdown]
# ## DataFrame を定義する

# %% [markdown]
# ### 既に作ってあるファイルを読み込む

# %%
# sample_data.csv を読み込んでみる

sample_data = pd.read_csv('sample_data.csv')

# show
sample_data.head()
# Out:
#   name      c1      c2      c3      c4
# 0    A  0.6871  0.8561  0.1958  0.6359
# 1    B  0.2590  0.0779  0.0782  0.1613
# 2    C  0.1801  0.5530  0.3060  0.5204
# 3    D  0.6558  0.9598  0.4819  0.2881
# 4    E  0.2013  0.7098  0.8028  0.0830

# %%
# sample_data.csv を読み込んでみる (2)
# インデックス列として既存のデータを使用する

sample_data = pd.read_csv('sample_data.csv', index_col='name')

# show
sample_data.head()
# Out:
#           c1      c2      c3      c4
# name
# A     0.6871  0.8561  0.1958  0.6359
# B     0.2590  0.0779  0.0782  0.1613
# C     0.1801  0.5530  0.3060  0.5204
# D     0.6558  0.9598  0.4819  0.2881
# E     0.2013  0.7098  0.8028  0.0830

# %% [markdown]
# ### 新たに DataFrame を定義する
#
# ディクショナリを用いる

# %%
# ディクショナリを用いて DaraFrameを定義する

# データ
cities = ['Tokyo', 'Shanghai', 'London', 'Moscow']
climates = ['Cfa', 'Cfa', 'Cfb', 'Dfb']
populations = [3814000, 3400000, 1400000, 17200000]

# 定義 インデックス有

cities_data = DataFrame(
    {
        'climate': climates,
        'population': populations
    },
    index=cities)

# show
cities_data
# Out:
#          climate  population
# Tokyo        Cfa     3814000
# Shanghai     Cfa     3400000
# London       Cfb     1400000
# Moscow       Dfb    17200000

# %%
# 定義 インデックス無

cities_noindex = DataFrame({
    'cities': cities,
    'climate': climates,
    'population': populations,
})

# show
cities_noindex
# Out:
#      cities climate  population
# 0     Tokyo     Cfa     3814000
# 1  Shanghai     Cfa     3400000
# 2    London     Cfb     1400000
# 3    Moscow     Dfb    17200000
